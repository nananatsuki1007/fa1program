# %% [markdown]
# <a href="https://colab.research.google.com/github/nananatsuki1007/fa1program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = str(input("Put in your name! "))
age = int(input("Put in your age!! "))
course = str(input("Put in your course!!! "))

print("Name: ", name)
print("Age: ", age)
print("Course: ", course)
# Out:
# Put in your name!!! Annalou
# Put in your age!!! 19
# Put in your course!!! Psychology
# Name:  Annalou
# Age:  19
# Course:  Psychology

# %%
score = int(input("Put in your score. "))

if score >= 75:
  print("AYO YOU PASSED CONGRATS MATE")
else:
    print("aww its ok try again next time C:")
# Out:
# Put in your score. 74
# aww its ok try again next time C:

# %%
str(input("What is YOUR name? "))
grade = int(input("What grade did you get? (NUMERIC) "))

if grade == 100 and grade >= 90:
  print("A")
elif grade <= 89 and grade >= 80:
  print("B")
elif grade <= 79 and grade >= 70:
  print("C")
elif grade <= 69 and grade >= 60:
  print("D")
else
  print("F")
# Out:
# What is YOUR name? s
# What grade did you get? (NUMERIC) 83
# B-
